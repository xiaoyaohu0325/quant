# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

sns.set_theme()

# %%
import viz
import importlib
importlib.reload(viz)

viz.plot("sz50", 2005)

# %%
viz.plot("hz300", 2012)

# %%
viz.plot("zz500", 2019)

# %%
import viz
import importlib
importlib.reload(viz)

viz.plot_between("sz50", "2013-05-01", "2013-05-15")
